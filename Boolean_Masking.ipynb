# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammad-umar-9/Python-Codes/blob/main/Boolean_Masking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Instantiate a dictionary of planetary data.
planet_data = { 'planet':['Mercury' , 'Venus', 'Earth', 'Mars',
                   'Jupiter', 'Saturn', 'Uranus', 'Neptune'],
                'radius':[2440, 6052, 6371, 3390, 69911, 58232,
                     25362, 24622] ,
                'Moons':[0, 0, 1, 2, 80, 83, 27, 14]

}
# Use pd.DataFrame() function to convert dictionary to dataframe.
planet = pd.DataFrame(planet_data)
planet
# Out:
#     planet  radius  Moons
# 0  Mercury    2440      0
# 1    Venus    6052      0
# 2    Earth    6371      1
# 3     Mars    3390      2
# 4  Jupiter   69911     80
# 5   Saturn   58232     83
# 6   Uranus   25362     27
# 7  Neptune   24622     14

# %%
# Create a Boolean mask of planets with fewer than 20 moons.
mask = planet['Moons'] < 20
mask
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Moons, dtype: bool

# %%
planet[mask]
# Out:
#     planet  radius  Moons
# 0  Mercury    2440      0
# 1    Venus    6052      0
# 2    Earth    6371      1
# 3     Mars    3390      2
# 7  Neptune   24622     14

# %%
# Boolean masks don't change the data. They're just views.
planet
# Out:
#     planet  radius  Moons
# 0  Mercury    2440      0
# 1    Venus    6052      0
# 2    Earth    6371      1
# 3     Mars    3390      2
# 4  Jupiter   69911     80
# 5   Saturn   58232     83
# 6   Uranus   25362     27
# 7  Neptune   24622     14

# %%
# You can assign a dataframe view to a named variable.
moons_under_20 = planet[mask]
moons_under_20
# Out:
#     planet  radius  Moons
# 0  Mercury    2440      0
# 1    Venus    6052      0
# 2    Earth    6371      1
# 3     Mars    3390      2
# 7  Neptune   24622     14

# %%
mask = (planet['Moons'] > 20) | (planet['radius'] > 25000)
mask
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# dtype: bool

# %%
planet[mask]
# Out:
#     planet  radius  Moons
# 4  Jupiter   69911     80
# 5   Saturn   58232     83
# 6   Uranus   25362     27

# %%
# Create a Boolean mask of planets with more than 20 moons, excluding them if they
# have 80 moons or if their radius is less than 50,000 km.
mask = (planet['Moons'] > 20) & ~(planet['Moons'] == 80) & (planet['radius'] < 50000)
mask
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# dtype: bool

# %%
# Apply the mask
planet[mask]
# Out:
#    planet  radius  Moons
# 6  Uranus   25362     27
